# %% [markdown]
# <h3 style="text-align: center;">EXPERIMENT- 2</h3>
# <h3 style="text-align: center;">Basic operation on signals</h3>
#
# ##### DATE: 21/08/2023
#
# ##### AIM:
# Write a program to reverse, shift, scale and shift plus scale in the continuous and discrete signal. Plot the results.
#
# ##### SOFTWARE USED:
# Python
#
# ##### THEORY:
# Basic signal operations manipulate the signal characteristics by acting on the independent variables which are used to represent them. This means that instead of performing operations like addition, subtraction, and multiplication between signals, we will perform them on the independent variables. Some of the common operations are:
#
# 1. <p>Time reversal: y[n] = -1.x[n]</p>
# 2. <p>Time shifting: y[n] = x[n ± n0]</p>
# 3. <p>Time scaling: y[n] = a * x[n]</p>
# 4. <p>Time shifting plus time scaling: y[n] = a.x[n ± n0]</p>
# ##### CODE:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Continuous Signal:
f = float(input("Enter the frequency of the signal :"))
t = np.arange (0,1,0.01)
y = np.sin(2*np.pi*f*t)
plt.plot(t,y)
plt.title("Continuos Signal-Original signal")
plt.show()
# Out:
# Enter the frequency of the signal : 4

# %%
#Time Reversal:

tr=np.zeros(len(t))
for i in range (0,len(t)):
  tr[i]=-1*t[len(t)-1-i]

yr= -1*(np.sin(2*np.pi*f*t))
plt.plot(tr,yr)
plt.show()

# %%
#Shifting of signal:
k = int(input("Enter the shifting factor :"))
tl = [x - k for x in t]
plt.subplot(1,2,1)
plt.plot(tl,y)
plt.title ("Left shift")
tr = [x + k for x in t]
plt.subplot(1,2,2)
plt.plot(tr,y)
plt.title ("Right shift")
plt.show()
# Out:
# Enter the shifting factor : 2

# %%
#Scaling of signal:
a = int(input("Enter the scaling factor :"))
s = [x * a for x in t]
plt.plot(s,y)
plt.title("Up-Scaling")
plt.show()
# Out:
# Enter the scaling factor : 2

# %%
#Time shifting plus time scaling:

#left shifting and upscaling of signal
upl = [a*(x - k) for x in t]
plt.subplot(1,2,1)
plt.plot (upl,y)
plt.title("Left shifting,then Up-Scaling")

#right shifting and upscaling of signal
upr = [a*(x + k) for x in t]
plt.subplot(1,2,2)
plt.plot (upr,y)
plt.title("Right shifting,then Up-Scaling")
plt.show()

# %%
#Discrete signal:
u,l,step = input("Enter the input sequence:").split(",",3)
t=np.arange(float(u),float(l)+1,float(step))
y=np.zeros(len(t))
for i in range (0,len(t)):
  y[i]=t[i]
plt.stem(t,y)
plt.title("Discrete Signal-Original signal")
plt.show()
# Out:
# Enter the input sequence: 1,5,0.2

# %%
#Time reversal:
tr=np.zeros(len(t))
for i in range (0,len(t)):
  tr[i]=-1*t[len(t)-1-i]
yr=np.zeros(len(t))
for i in range (0,len(t)):
  yr[i]=1*t[len(tr)-1-i]
plt.stem(tr,yr)
plt.show()

# %%
#Shifting of signal:
k = int(input("Enter the shifting factor :"))
tl = [x - k for x in t]
plt.subplot(1,2,1)
plt.stem(tl,y)
plt.title ("Left shift")
tr = [x + k for x in t]
plt.subplot(1,2,2)
plt.stem(tr,y)
plt.title ("Right shift")
plt.show()
# Out:
# Enter the shifting factor : 3

# %%
#Scaling of signal:
a = int(input("Enter the scaling factor :"))
s = [x * a for x in t]
plt.stem(s,y)
plt.title("Up-Scaling")
plt.show()
# Out:
# Enter the scaling factor : 3

# %%
#Time shifting plus time scaling:

#left shifting and upscaling of signal
upl = [a*(x - k) for x in t]
plt.subplot(1,2,1)
plt.stem (upl,y)
plt.title("Left shifting,then Up-Scaling")

#right shifting and upscaling of signal
upr = [a*(x + k) for x in t]
plt.subplot(1,2,2)
plt.stem (upr,y)
plt.title("Right shifting,then Up-Scaling")
plt.show()

# %% [markdown]
# ##### RESULT:
# Successfully performed basic operations on signals.
